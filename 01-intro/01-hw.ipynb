# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
df = pd.read_csv("C:/zoom-ml/01-intro/dataset/car.csv")

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.head(5)
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.groupby('origin').fuel_efficiency_mpg.max()
# Out:
# origin
# Asia      41.2
# Europe    39.4
# USA       38.2
# Name: fuel_efficiency_mpg, dtype: float64

# %% [markdown]
# ### Q6. Median

# %%
med_hp = df.horsepower.median()
med_hp
# Out:
# np.float64(254.0)

# %%
mod_hp = df.horsepower.mode()
mod_hp
# Out:
# 0    252.0
# Name: horsepower, dtype: float64

# %%
df['horsepower'].isnull().any()
# Out:
# np.True_

# %%
df['horsepower'] = df['horsepower'].fillna(mod_hp[0])
df['horsepower'].isnull().any()
# Out:
# np.False_

# %%
df['horsepower'].median()
# Out:
# np.float64(252.0)

# %%
df.vehicle_weight.sum()
# Out:
# np.int64(42867540)

# %% [markdown]
# ### Q.7 Sum of weights

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
